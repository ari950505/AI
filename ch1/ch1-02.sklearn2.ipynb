# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
iris = load_iris()
x_train, x_test, y_train, y_test = train_test_split(iris.data,
                                 iris.target,
                                 test_size=0.3,
                                 random_state=11)

# %%
k_list = range(1,100,2)
acc_train =[]
acc_test =[]

#k 변경하면서 knn 모델 학습 및 검증 수행
for k in k_list:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train,y_train)
    
    acc_train.append(knn.score(x_train, y_train))
    acc_test.append(knn.score(x_test,y_test))
print('acc_train:\n',acc_train)
print(len(acc_train))
print('acc_test:\n',acc_test)
# Out:
# acc_train:
#  [1.0, 0.9714285714285714, 0.9714285714285714, 0.9809523809523809, 0.9809523809523809, 0.9809523809523809, 0.9809523809523809, 0.9714285714285714, 0.9619047619047619, 0.9523809523809523, 0.9619047619047619, 0.9619047619047619, 0.9619047619047619, 0.9714285714285714, 0.9714285714285714, 0.9714285714285714, 0.9714285714285714, 0.9523809523809523, 0.9428571428571428, 0.9333333333333333, 0.9238095238095239, 0.9333333333333333, 0.9238095238095239, 0.9238095238095239, 0.9333333333333333, 0.9142857142857143, 0.8952380952380953, 0.9047619047619048, 0.9142857142857143, 0.8952380952380953, 0.8952380952380953, 0.9047619047619048, 0.8952380952380953, 0.6761904761904762, 0.6857142857142857, 0.6761904761904762, 0.6761904761904762, 0.6761904761904762, 0.6857142857142857, 0.6761904761904762, 0.6761904761904762, 0.6761904761904762, 0.6666666666666666, 0.6571428571428571, 0.6571428571428571, 0.6571428571428571, 0.6571428571428571, 0.6571428571428571, 0.6476190476190476, 0.6476190476190476]
# 50
# acc_test:
#  [0.9333333333333333, 0.9555555555555556, 0.9777777777777777, 0.9777777777777777, 0.9777777777777777, 0.9333333333333333, 0.9555555555555556, 0.9555555555555556, 0.9333333333333333, 0.9111111111111111, 0.9333333333333333, 0.8888888888888888, 0.8888888888888888, 0.8888888888888888, 0.9111111111111111, 0.9111111111111111, 0.9333333333333333, 0.9111111111111111, 0.9111111111111111, 0.8666666666666667, 0.8666666666666667, 0.8666666666666667, 0.8444444444444444, 0.8666666666666667, 0.8666666666666667, 0.8444444444444444, 0.8444444444444444, 0.8444444444444444, 0.8666666666666667, 0.8666666666666667, 0.8444444444444444, 0.8666666666666667, 0.8666666666666667, 0.6222222222222222, 0.6222222222222222, 0.6222222222222222, 0.6222222222222222, 0.6222222222222222, 0.6222222222222222, 0.6222222222222222, 0.6222222222222222, 0.6222222222222222, 0.6222222222222222, 0.6222222222222222, 0.6222222222222222, 0.6222222222222222, 0.6, 0.6, 0.6, 0.6]

# %%
# 시각화
plt.figure(figsize=(10,4))
plt.plot(k_list, acc_train,'b--',label='Traing')
plt.plot(k_list, acc_test,'g',label='Testing')
plt.title('Training and Testing Accuracy')
plt.xlabel('K')
plt.ylabel('Accuracy')
plt.ylim(0.8,1.0)
plt.show()
